# %% [markdown]
# <a href="https://colab.research.google.com/github/luciapintor/isde_tests/blob/main/2021_10_05_gaussian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Homeworks

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(100, 1)
plt.plot(x)
